# %%
import pandas as pd
df=pd.read_csv("sales_data.csv")

df.head()
# Out:
#    Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0        1052  2023-02-03       Bob  North       5053.97             18
# 1        1093  2023-04-21       Bob   West       4384.02             17
# 2        1015  2023-09-21     David  South       4631.23             30
# 3        1072  2023-08-24       Bob  South       2167.94             39
# 4        1061  2023-03-24   Charlie   East       3750.20             13
#
#   Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# 0        Furniture     152.75      267.22     Returning      0.09
# 1        Furniture    3816.39     4209.44     Returning      0.11
# 2             Food     261.56      371.40     Returning      0.20
# 3         Clothing    4330.03     4467.75           New      0.02
# 4      Electronics     637.37      692.71           New      0.08
#
#   Payment_Method Sales_Channel Region_and_Sales_Rep
# 0           Cash        Online            North-Bob
# ...

# %%
df.columns=df.columns.str.lower()

# %%
df.describe()
# Out:
#         product_id  sales_amount  quantity_sold    unit_cost   unit_price  \
# count  1000.000000   1000.000000    1000.000000  1000.000000  1000.000000
# mean   1050.128000   5019.265230      25.355000  2475.304550  2728.440120
# std      29.573505   2846.790126      14.159006  1417.872546  1419.399839
# min    1001.000000    100.120000       1.000000    60.280000   167.120000
# 25%    1024.000000   2550.297500      13.000000  1238.380000  1509.085000
# 50%    1051.000000   5019.300000      25.000000  2467.235000  2696.400000
# 75%    1075.000000   7507.445000      38.000000  3702.865000  3957.970000
# max    1100.000000   9989.040000      49.000000  4995.300000  5442.150000
#
#          discount
# count  1000.00000
# mean      0.15239
# std       0.08720
# min       0.00000
# 25%       0.08000
# 50%       0.15000
# 75%       0.23000
# max       0.30000

# %%
df.isnull().sum()
# Out:
# product_id              0
# sale_date               0
# sales_rep               0
# region                  0
# sales_amount            0
# quantity_sold           0
# product_category        0
# unit_cost               0
# unit_price              0
# customer_type           0
# discount                0
# payment_method          0
# sales_channel           0
# region_and_sales_rep    0
# dtype: int64

# %%
df["total_revenue"]=df["quantity_sold"] * df["unit_price"]
df["total_revenue"]
# Out:
# 0        4809.96
# 1       71560.48
# 2       11142.00
# 3      174242.25
# 4        9005.23
#          ...
# 995     21768.60
# 996     68686.80
# 997      7450.59
# 998    145992.21
# 999    140480.64
# Name: total_revenue, Length: 1000, dtype: float64

# %%
df.head()
# Out:
#    product_id   sale_date sales_rep region  sales_amount  quantity_sold  \
# 0        1052  2023-02-03       Bob  North       5053.97             18
# 1        1093  2023-04-21       Bob   West       4384.02             17
# 2        1015  2023-09-21     David  South       4631.23             30
# 3        1072  2023-08-24       Bob  South       2167.94             39
# 4        1061  2023-03-24   Charlie   East       3750.20             13
#
#   product_category  unit_cost  unit_price customer_type  discount  \
# 0        Furniture     152.75      267.22     Returning      0.09
# 1        Furniture    3816.39     4209.44     Returning      0.11
# 2             Food     261.56      371.40     Returning      0.20
# 3         Clothing    4330.03     4467.75           New      0.02
# 4      Electronics     637.37      692.71           New      0.08
#
#   payment_method sales_channel region_and_sales_rep  total_revenue
# 0           Cash        Online            North-Bob        4809.96
# ...

# %%
df.groupby("payment_method")["total_revenue"].mean()
# Out:
# payment_method
# Bank Transfer    71912.498538
# Cash             70896.202843
# Credit Card      68247.404986
# Name: total_revenue, dtype: float64

# %%
df.iloc[:2,:-3]
# Out:
#    product_id   sale_date sales_rep region  sales_amount  quantity_sold  \
# 0        1052  2023-02-03       Bob  North       5053.97             18
# 1        1093  2023-04-21       Bob   West       4384.02             17
#
#   product_category  unit_cost  unit_price customer_type  discount  \
# 0        Furniture     152.75      267.22     Returning      0.09
# 1        Furniture    3816.39     4209.44     Returning      0.11
#
#   payment_method
# 0           Cash
# 1           Cash

# %%
df.shape
# Out:
# (1000, 15)

# %%
df.describe(include="all")
df.dtypes
# Out:
# product_id                int64
# sale_date                object
# sales_rep                object
# region                   object
# sales_amount            float64
# quantity_sold             int64
# product_category         object
# unit_cost               float64
# unit_price              float64
# customer_type            object
# discount                float64
# payment_method           object
# sales_channel            object
# region_and_sales_rep     object
# total_revenue           float64
# dtype: object

# %%
df[["product_category","total_revenue"]].head()
# Out:
#   product_category  total_revenue
# 0        Furniture        4809.96
# 1        Furniture       71560.48
# 2             Food       11142.00
# 3         Clothing      174242.25
# 4      Electronics        9005.23

# %%
(df[df["unit_price"]>500]).sort_values(by="unit_price",ascending=False)
# Out:
#      product_id   sale_date sales_rep region  sales_amount  quantity_sold  \
# 995        1010  2023-04-15   Charlie  North       4733.88              4
# 764        1100  2023-12-01     Alice   East       1387.80             34
# 806        1001  2023-05-10     David   East       3793.91             47
# 807        1021  2023-06-24     Alice   West       9422.75             24
# 840        1026  2023-03-20       Bob   East        614.69             19
# ..          ...         ...       ...    ...           ...            ...
# 92         1087  2023-04-05       Eve   East        848.49             43
# 619        1100  2023-09-17   Charlie  North       4795.12             17
# 944        1086  2023-12-28       Bob   West       1837.37             46
# 986        1086  2023-10-20     David  South       3577.07             32
# 873        1098  2024-01-01       Bob  South       2370.72             11
#
#     product_category  unit_cost  unit_price customer_type  discount  \
# ...

# %%
df[df["region"]=="South"]
# Out:
#      product_id   sale_date sales_rep region  sales_amount  quantity_sold  \
# 2          1015  2023-09-21     David  South       4631.23             30
# 3          1072  2023-08-24       Bob  South       2167.94             39
# 7          1087  2023-01-06       Eve  South       7698.92             46
# 8          1075  2023-06-29     David  South       4223.39             30
# 13         1003  2023-12-31     Alice  South       4775.59             30
# ..          ...         ...       ...    ...           ...            ...
# 962        1090  2023-10-15   Charlie  South       9702.27             48
# 970        1059  2023-11-08     David  South       8466.70             17
# 986        1086  2023-10-20     David  South       3577.07             32
# 994        1068  2023-04-06     Alice  South       9093.50             31
# 997        1018  2023-04-27     David  South       7629.70             17
#
#     product_category  unit_cost  unit_price customer_type  discount  \
# ...

# %%
df[(df["quantity_sold"]>=5)&(df["unit_price"]<=500) ]
# Out:
#      product_id   sale_date sales_rep region  sales_amount  quantity_sold  \
# 0          1052  2023-02-03       Bob  North       5053.97             18
# 2          1015  2023-09-21     David  South       4631.23             30
# 15         1053  2023-10-16       Bob  North       2235.83             48
# 118        1008  2023-12-05   Charlie   East       9583.55             27
# 150        1027  2023-01-15       Bob   West       6261.20             26
# 178        1062  2023-05-16   Charlie  North       8495.62             46
# 336        1017  2023-02-20   Charlie  North       8189.57             16
# 372        1099  2023-10-20     David  South       7859.22             23
# 427        1014  2023-11-09     David  North       6016.92              9
# 430        1015  2023-08-07     Alice   East       1148.47             19
# 461        1096  2023-04-08   Charlie  South       5935.59             45
# 474        1019  2023-09-01     David   West       2550.84             16
# ...

# %%
df.iloc[:10]
# Out:
#    product_id   sale_date sales_rep region  sales_amount  quantity_sold  \
# 0        1052  2023-02-03       Bob  North       5053.97             18
# 1        1093  2023-04-21       Bob   West       4384.02             17
# 2        1015  2023-09-21     David  South       4631.23             30
# 3        1072  2023-08-24       Bob  South       2167.94             39
# 4        1061  2023-03-24   Charlie   East       3750.20             13
# 5        1021  2023-02-11   Charlie   West       3761.15             32
# 6        1083  2023-04-11       Bob   West        618.31             29
# 7        1087  2023-01-06       Eve  South       7698.92             46
# 8        1075  2023-06-29     David  South       4223.39             30
# 9        1075  2023-10-09   Charlie   West       8239.58             18
#
#   product_category  unit_cost  unit_price customer_type  discount  \
# 0        Furniture     152.75      267.22     Returning      0.09
# ...

# %%
print(df["total_revenue"].max())
print(df["quantity_sold"].mean())
# Out:
# 252147.36
# 25.355

# %%
df.sort_values(by="total_revenue",ascending=False)
# Out:
#      product_id   sale_date sales_rep region  sales_amount  quantity_sold  \
# 962        1090  2023-10-15   Charlie  South       9702.27             48
# 806        1001  2023-05-10     David   East       3793.91             47
# 170        1032  2023-06-08       Eve   West        219.82             49
# 843        1003  2023-02-19     Alice   East        937.20             45
# 510        1047  2023-08-04       Eve  South        733.66             47
# ..          ...         ...       ...    ...           ...            ...
# 610        1017  2023-10-29       Eve   East       2141.90              1
# 799        1059  2023-04-09   Charlie  South       8063.70              1
# 243        1017  2023-07-21     David   East       3388.69              1
# 692        1090  2023-11-14       Bob   East       6575.91              1
# 162        1004  2023-11-18     Alice   East       7211.48              1
#
#     product_category  unit_cost  unit_price customer_type  discount  \
# ...

# %%
df.groupby("product_category")["total_revenue"].mean().round(2)
# Out:
# product_category
# Clothing       71965.43
# Electronics    71426.99
# Food           66999.49
# Furniture      70501.08
# Name: total_revenue, dtype: float64

# %%
df.sort_values(by="total_revenue",ascending=False)[["product_category","total_revenue"]]
# Out:
#     product_category  total_revenue
# 962      Electronics      252147.36
# 806             Food      249858.11
# 170      Electronics      249312.00
# 843      Electronics      235256.85
# 510         Clothing      233903.96
# ..               ...            ...
# 610        Furniture         752.24
# 799      Electronics         612.46
# 243             Food         404.69
# 692         Clothing         260.73
# 162             Food         211.18
#
# [1000 rows x 2 columns]

# %%
df.groupby("product_category")["total_revenue"].sum()
# Out:
# product_category
# Clothing       19286733.93
# Electronics    17571040.57
# Food           15141885.65
# Furniture      18330280.56
# Name: total_revenue, dtype: float64

# %%
df.groupby("region_and_sales_rep")["unit_price"].mean()
# Out:
# region_and_sales_rep
# East-Alice       2733.579808
# East-Bob         2639.085333
# East-Charlie     2656.927568
# East-David       2751.441864
# East-Eve         2882.715273
# North-Alice      2526.594375
# North-Bob        2938.389773
# North-Charlie    2506.159091
# North-David      2831.605893
# North-Eve        2756.776563
# South-Alice      2989.630667
# South-Bob        2732.159400
# South-Charlie    2624.524688
# South-David      2240.428393
# South-Eve        3033.164884
# West-Alice       2733.073404
# West-Bob         2605.778333
# West-Charlie     3120.402444
# West-David       2632.767255
# West-Eve         2776.130213
# Name: unit_price, dtype: float64

# %%
df["sale_date"]=pd.to_datetime(df["sale_date"])
df["month"]=df["sale_date"].dt.month
df["monthname"]=df["sale_date"].dt.month_name()
df["year"]=df["sale_date"].dt.year
df[["month","monthname","year"]]
# Out:
#      month  monthname  year
# 0        2   February  2023
# 1        4      April  2023
# 2        9  September  2023
# 3        8     August  2023
# 4        3      March  2023
# ..     ...        ...   ...
# 995      4      April  2023
# 996      9  September  2023
# 997      4      April  2023
# 998     12   December  2023
# 999      8     August  2023
#
# [1000 rows x 3 columns]

# %%
df.groupby("monthname")["total_revenue"].sum()
# Out:
# monthname
# April        5468497.62
# August       6716190.61
# December     6250242.79
# February     5627477.45
# January      7488100.51
# July         4751432.42
# June         6142561.23
# March        6008259.41
# May          5800626.51
# November     4958930.19
# October      6560606.39
# September    4557015.58
# Name: total_revenue, dtype: float64

# %%
df["sale_date"].head()
# Out:
# 0   2023-02-03
# 1   2023-04-21
# 2   2023-09-21
# 3   2023-08-24
# 4   2023-03-24
# Name: sale_date, dtype: datetime64[ns]

# %%
df[df["sale_date"]>"2021-01-03"]
# Out:
#      product_id  sale_date sales_rep region  sales_amount  quantity_sold  \
# 0          1052 2023-02-03       Bob  North       5053.97             18
# 1          1093 2023-04-21       Bob   West       4384.02             17
# 2          1015 2023-09-21     David  South       4631.23             30
# 3          1072 2023-08-24       Bob  South       2167.94             39
# 4          1061 2023-03-24   Charlie   East       3750.20             13
# ..          ...        ...       ...    ...           ...            ...
# 995        1010 2023-04-15   Charlie  North       4733.88              4
# 996        1067 2023-09-07       Bob  North       4716.36             37
# 997        1018 2023-04-27     David  South       7629.70             17
# 998        1100 2023-12-20     David   West       1629.47             39
# 999        1086 2023-08-16     Alice   East       4923.93             48
#
#     product_category  unit_cost  unit_price customer_type  discount  \
# ...

# %%
df.to_csv("cleaned_sales_data.csv",index=False)

# %%
df.drop(columns=["sale_date"])
df.drop(df[df["total_revenue"]<2000].index)
del df["total_revenue"]

# %%
df.head()
# Out:
#    product_id  sale_date sales_rep region  sales_amount  quantity_sold  \
# 0        1052 2023-02-03       Bob  North       5053.97             18
# 1        1093 2023-04-21       Bob   West       4384.02             17
# 2        1015 2023-09-21     David  South       4631.23             30
# 3        1072 2023-08-24       Bob  South       2167.94             39
# 4        1061 2023-03-24   Charlie   East       3750.20             13
#
#   product_category  unit_cost  unit_price customer_type  discount  \
# 0        Furniture     152.75      267.22     Returning      0.09
# 1        Furniture    3816.39     4209.44     Returning      0.11
# 2             Food     261.56      371.40     Returning      0.20
# 3         Clothing    4330.03     4467.75           New      0.02
# 4      Electronics     637.37      692.71           New      0.08
#
#   payment_method sales_channel region_and_sales_rep  month  monthname  year
# ...
